# %%
import pygeog510

# %%
i_map = pygeog510.ipyMap(height="500px", zoom=3)

# %%
i_map.add_geojson(
    "https://github.com/opengeos/datasets/releases/download/us/us_southeast.geojson"
)

i_map.add_layer_control()

i_map
